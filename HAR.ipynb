# %% [markdown]
# consider opening in colab for better output display.
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mohammad-dabash22/HAR_Analysis/blob/main/HAR.ipynb)

# %% [markdown]
# # Create a Spark session

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder\
        .master("local")\
        .appName("Colab")\
        .config('spark.ui.port', '4050')\
        .getOrCreate()

spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://7c8547fe9526:4050">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Colab</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# # Load and Explore the Dataset

# %%
df = spark.read.format("csv").load("HAR_3000.csv", header=True, inferSchema=True)

df.printSchema()
# Out:
# root
#  |-- tBodyAcc-mean()-X: double (nullable = true)
#  |-- tBodyAcc-mean()-Y: double (nullable = true)
#  |-- tBodyAcc-mean()-Z: double (nullable = true)
#  |-- tBodyAcc-std()-X: double (nullable = true)
#  |-- tBodyAcc-std()-Y: double (nullable = true)
#  |-- tBodyAcc-std()-Z: double (nullable = true)
#  |-- tBodyAcc-mad()-X: double (nullable = true)
#  |-- tBodyAcc-mad()-Y: double (nullable = true)
#  |-- tBodyAcc-mad()-Z: double (nullable = true)
#  |-- tBodyAcc-max()-X: double (nullable = true)
#  |-- tBodyAcc-max()-Y: double (nullable = true)
#  |-- tBodyAcc-max()-Z: double (nullable = true)
#  |-- tBodyAcc-min()-X: double (nullable = true)
#  |-- tBodyAcc-min()-Y: double (nullable = true)
#  |-- tBodyAcc-min()-Z: double (nullable = true)
#  |-- tBodyAcc-sma(): double (nullable = true)
#  |-- tBodyAcc-energy()-X: double (nullable = true)
#  |-- tBodyAcc-energy()-Y: double (nullable = true)
#  |-- tBodyAcc-energy()-Z: double (nullable = true)
#  |-- tBodyAcc-iqr()-X: double (nullable = true)
#  |-- tBodyAcc-iqr()-Y: double (nullable = true)
#  |-- tBodyAcc-iqr()-Z: double (nullable = true)
#  |-- tBodyAcc-entropy()-X: double (nullable = true)
#  |-- tBodyAcc-entropy()-Y: double (nullable = true)
#  |-- tBodyAcc-entropy()-Z: double (nullable = true)
#  |-- tBodyAcc-arCoeff()-X,1: double (nullable = true)
#  |-- tBodyAcc-arCoeff()-X,2: double (nullable = true)
#  |-- tBodyAcc-arCoeff()-X,3: double (nullable = true)
#  |-- tBodyAcc-arCoeff()-X,4: double (nullable = true)
#  |-- tBodyAcc-arCoeff()-Y,1: double (nullable = true)
#  |-- tBodyAcc-arCoeff()-Y,2: double (nullable = true)
#  |-- tBodyAcc-arCoeff()-Y,3: double (nullable = true)
#  |-- tBodyAcc-arCoeff()-Y,4: double (nullable = true)
#  |-- tBodyAcc-arCoeff()-Z,1: double (nullable = true)
#  |-- tBodyAcc-arCoeff()-Z,2: double (nullable = true)
#  |-- tBodyAcc-arCoeff()-Z,3: double (nullable = true)
#  |-- tBodyAcc-arCoeff()-Z,4: double (nullable = true)
#  |-- tBodyAcc-correlation()-X,Y: double (nullable = true)
#  |-- tBodyAcc-correlation()-X,Z: double (nullable = true)
#  |-- tBodyAcc-correlation()-Y,Z: double (nullable = true)
#  |-- tGravityAcc-mean()-X: double (nullable = true)
#  |-- tGravityAcc-mean()-Y: double (nullable = true)
#  |-- tGravityAcc-mean()-Z: double (nullable = true)
#  |-- tGravityAcc-std()-X: double (nullable = true)
#  |-- tGravityAcc-std()-Y: double (nullable = true)
#  |-- tGravityAcc-std()-Z: double (nullable = true)
#  |-- tGravityAcc-mad()-X: double (nullable = true)
#  |-- tGravityAcc-mad()-Y: double (nullable = true)
#  |-- tGravityAcc-mad()-Z: double (nullable = true)
#  |-- tGravityAcc-max()-X: double (nullable = true)
#  |-- tGravityAcc-max()-Y: double (nullable = true)
#  |-- tGravityAcc-max()-Z: double (nullable = true)
#  |-- tGravityAcc-min()-X: double (nullable = true)
#  |-- tGravityAcc-min()-Y: double (nullable = true)
#  |-- tGravityAcc-min()-Z: double (nullable = true)
#  |-- tGravityAcc-sma(): double (nullable = true)
#  |-- tGravityAcc-energy()-X: double (nullable = true)
#  |-- tGravityAcc-energy()-Y: double (nullable = true)
#  |-- tGravityAcc-energy()-Z: double (nullable = true)
#  |-- tGravityAcc-iqr()-X: double (nullable = true)
#  |-- tGravityAcc-iqr()-Y: double (nullable = true)
#  |-- tGravityAcc-iqr()-Z: double (nullable = true)
#  |-- tGravityAcc-entropy()-X: double (nullable = true)
#  |-- tGravityAcc-entropy()-Y: double (nullable = true)
#  |-- tGravityAcc-entropy()-Z: double (nullable = true)
#  |-- tGravityAcc-arCoeff()-X,1: double (nullable = true)
#  |-- tGravityAcc-arCoeff()-X,2: double (nullable = true)
#  |-- tGravityAcc-arCoeff()-X,3: double (nullable = true)
#  |-- tGravityAcc-arCoeff()-X,4: double (nullable = true)
#  |-- tGravityAcc-arCoeff()-Y,1: double (nullable = true)
#  |-- tGravityAcc-arCoeff()-Y,2: double (nullable = true)
#  |-- tGravityAcc-arCoeff()-Y,3: double (nullable = true)
#  |-- tGravityAcc-arCoeff()-Y,4: double (nullable = true)
#  |-- tGravityAcc-arCoeff()-Z,1: double (nullable = true)
#  |-- tGravityAcc-arCoeff()-Z,2: double (nullable = true)
#  |-- tGravityAcc-arCoeff()-Z,3: double (nullable = true)
#  |-- tGravityAcc-arCoeff()-Z,4: double (nullable = true)
#  |-- tGravityAcc-correlation()-X,Y: double (nullable = true)
#  |-- tGravityAcc-correlation()-X,Z: double (nullable = true)
#  |-- tGravityAcc-correlation()-Y,Z: double (nullable = true)
#  |-- tBodyAccJerk-mean()-X: double (nullable = true)
#  |-- tBodyAccJerk-mean()-Y: double (nullable = true)
#  |-- tBodyAccJerk-mean()-Z: double (nullable = true)
#  |-- tBodyAccJerk-std()-X: double (nullable = true)
#  |-- tBodyAccJerk-std()-Y: double (nullable = true)
#  |-- tBodyAccJerk-std()-Z: double (nullable = true)
#  |-- tBodyAccJerk-mad()-X: double (nullable = true)
#  |-- tBodyAccJerk-mad()-Y: double (nullable = true)
#  |-- tBodyAccJerk-mad()-Z: double (nullable = true)
#  |-- tBodyAccJerk-max()-X: double (nullable = true)
#  |-- tBodyAccJerk-max()-Y: double (nullable = true)
#  |-- tBodyAccJerk-max()-Z: double (nullable = true)
#  |-- tBodyAccJerk-min()-X: double (nullable = true)
#  |-- tBodyAccJerk-min()-Y: double (nullable = true)
#  |-- tBodyAccJerk-min()-Z: double (nullable = true)
#  |-- tBodyAccJerk-sma(): double (nullable = true)
#  |-- tBodyAccJerk-energy()-X: double (nullable = true)
#  |-- tBodyAccJerk-energy()-Y: double (nullable = true)
#  |-- tBodyAccJerk-energy()-Z: double (nullable = true)
#  |-- tBodyAccJerk-iqr()-X: double (nullable = true)
#  |-- tBodyAccJerk-iqr()-Y: double (nullable = true)
#  |-- tBodyAccJerk-iqr()-Z: double (nullable = true)
#  |-- tBodyAccJerk-entropy()-X: double (nullable = true)
#  |-- tBodyAccJerk-entropy()-Y: double (nullable = true)
#  |-- tBodyAccJerk-entropy()-Z: double (nullable = true)
#  |-- tBodyAccJerk-arCoeff()-X,1: double (nullable = true)
#  |-- tBodyAccJerk-arCoeff()-X,2: double (nullable = true)
#  |-- tBodyAccJerk-arCoeff()-X,3: double (nullable = true)
#  |-- tBodyAccJerk-arCoeff()-X,4: double (nullable = true)
#  |-- tBodyAccJerk-arCoeff()-Y,1: double (nullable = true)
#  |-- tBodyAccJerk-arCoeff()-Y,2: double (nullable = true)
#  |-- tBodyAccJerk-arCoeff()-Y,3: double (nullable = true)
#  |-- tBodyAccJerk-arCoeff()-Y,4: double (nullable = true)
#  |-- tBodyAccJerk-arCoeff()-Z,1: double (nullable = true)
#  |-- tBodyAccJerk-arCoeff()-Z,2: double (nullable = true)
#  |-- tBodyAccJerk-arCoeff()-Z,3: double (nullable = true)
#  |-- tBodyAccJerk-arCoeff()-Z,4: double (nullable = true)
#  |-- tBodyAccJerk-correlation()-X,Y: double (nullable = true)
#  |-- tBodyAccJerk-correlation()-X,Z: double (nullable = true)
#  |-- tBodyAccJerk-correlation()-Y,Z: double (nullable = true)
#  |-- tBodyGyro-mean()-X: double (nullable = true)
#  |-- tBodyGyro-mean()-Y: double (nullable = true)
#  |-- tBodyGyro-mean()-Z: double (nullable = true)
#  |-- tBodyGyro-std()-X: double (nullable = true)
#  |-- tBodyGyro-std()-Y: double (nullable = true)
#  |-- tBodyGyro-std()-Z: double (nullable = true)
#  |-- tBodyGyro-mad()-X: double (nullable = true)
#  |-- tBodyGyro-mad()-Y: double (nullable = true)
#  |-- tBodyGyro-mad()-Z: double (nullable = true)
#  |-- tBodyGyro-max()-X: double (nullable = true)
#  |-- tBodyGyro-max()-Y: double (nullable = true)
#  |-- tBodyGyro-max()-Z: double (nullable = true)
#  |-- tBodyGyro-min()-X: double (nullable = true)
#  |-- tBodyGyro-min()-Y: double (nullable = true)
#  |-- tBodyGyro-min()-Z: double (nullable = true)
#  |-- tBodyGyro-sma(): double (nullable = true)
#  |-- tBodyGyro-energy()-X: double (nullable = true)
#  |-- tBodyGyro-energy()-Y: double (nullable = true)
#  |-- tBodyGyro-energy()-Z: double (nullable = true)
#  |-- tBodyGyro-iqr()-X: double (nullable = true)
#  |-- tBodyGyro-iqr()-Y: double (nullable = true)
#  |-- tBodyGyro-iqr()-Z: double (nullable = true)
#  |-- tBodyGyro-entropy()-X: double (nullable = true)
#  |-- tBodyGyro-entropy()-Y: double (nullable = true)
#  |-- tBodyGyro-entropy()-Z: double (nullable = true)
#  |-- tBodyGyro-arCoeff()-X,1: double (nullable = true)
#  |-- tBodyGyro-arCoeff()-X,2: double (nullable = true)
#  |-- tBodyGyro-arCoeff()-X,3: double (nullable = true)
#  |-- tBodyGyro-arCoeff()-X,4: double (nullable = true)
#  |-- tBodyGyro-arCoeff()-Y,1: double (nullable = true)
#  |-- tBodyGyro-arCoeff()-Y,2: double (nullable = true)
#  |-- tBodyGyro-arCoeff()-Y,3: double (nullable = true)
#  |-- tBodyGyro-arCoeff()-Y,4: double (nullable = true)
#  |-- tBodyGyro-arCoeff()-Z,1: double (nullable = true)
#  |-- tBodyGyro-arCoeff()-Z,2: double (nullable = true)
#  |-- tBodyGyro-arCoeff()-Z,3: double (nullable = true)
#  |-- tBodyGyro-arCoeff()-Z,4: double (nullable = true)
#  |-- tBodyGyro-correlation()-X,Y: double (nullable = true)
#  |-- tBodyGyro-correlation()-X,Z: double (nullable = true)
#  |-- tBodyGyro-correlation()-Y,Z: double (nullable = true)
#  |-- tBodyGyroJerk-mean()-X: double (nullable = true)
#  |-- tBodyGyroJerk-mean()-Y: double (nullable = true)
#  |-- tBodyGyroJerk-mean()-Z: double (nullable = true)
#  |-- tBodyGyroJerk-std()-X: double (nullable = true)
#  |-- tBodyGyroJerk-std()-Y: double (nullable = true)
#  |-- tBodyGyroJerk-std()-Z: double (nullable = true)
#  |-- tBodyGyroJerk-mad()-X: double (nullable = true)
#  |-- tBodyGyroJerk-mad()-Y: double (nullable = true)
#  |-- tBodyGyroJerk-mad()-Z: double (nullable = true)
#  |-- tBodyGyroJerk-max()-X: double (nullable = true)
#  |-- tBodyGyroJerk-max()-Y: double (nullable = true)
#  |-- tBodyGyroJerk-max()-Z: double (nullable = true)
#  |-- tBodyGyroJerk-min()-X: double (nullable = true)
#  |-- tBodyGyroJerk-min()-Y: double (nullable = true)
#  |-- tBodyGyroJerk-min()-Z: double (nullable = true)
#  |-- tBodyGyroJerk-sma(): double (nullable = true)
#  |-- tBodyGyroJerk-energy()-X: double (nullable = true)
#  |-- tBodyGyroJerk-energy()-Y: double (nullable = true)
#  |-- tBodyGyroJerk-energy()-Z: double (nullable = true)
#  |-- tBodyGyroJerk-iqr()-X: double (nullable = true)
#  |-- tBodyGyroJerk-iqr()-Y: double (nullable = true)
#  |-- tBodyGyroJerk-iqr()-Z: double (nullable = true)
#  |-- tBodyGyroJerk-entropy()-X: double (nullable = true)
#  |-- tBodyGyroJerk-entropy()-Y: double (nullable = true)
#  |-- tBodyGyroJerk-entropy()-Z: double (nullable = true)
#  |-- tBodyGyroJerk-arCoeff()-X,1: double (nullable = true)
#  |-- tBodyGyroJerk-arCoeff()-X,2: double (nullable = true)
#  |-- tBodyGyroJerk-arCoeff()-X,3: double (nullable = true)
#  |-- tBodyGyroJerk-arCoeff()-X,4: double (nullable = true)
#  |-- tBodyGyroJerk-arCoeff()-Y,1: double (nullable = true)
#  |-- tBodyGyroJerk-arCoeff()-Y,2: double (nullable = true)
#  |-- tBodyGyroJerk-arCoeff()-Y,3: double (nullable = true)
#  |-- tBodyGyroJerk-arCoeff()-Y,4: double (nullable = true)
#  |-- tBodyGyroJerk-arCoeff()-Z,1: double (nullable = true)
#  |-- tBodyGyroJerk-arCoeff()-Z,2: double (nullable = true)
#  |-- tBodyGyroJerk-arCoeff()-Z,3: double (nullable = true)
#  |-- tBodyGyroJerk-arCoeff()-Z,4: double (nullable = true)
#  |-- tBodyGyroJerk-correlation()-X,Y: double (nullable = true)
#  |-- tBodyGyroJerk-correlation()-X,Z: double (nullable = true)
#  |-- tBodyGyroJerk-correlation()-Y,Z: double (nullable = true)
#  |-- tBodyAccMag-mean(): double (nullable = true)
#  |-- tBodyAccMag-std(): double (nullable = true)
#  |-- tBodyAccMag-mad(): double (nullable = true)
#  |-- tBodyAccMag-max(): double (nullable = true)
#  |-- tBodyAccMag-min(): double (nullable = true)
#  |-- tBodyAccMag-sma(): double (nullable = true)
#  |-- tBodyAccMag-energy(): double (nullable = true)
#  |-- tBodyAccMag-iqr(): double (nullable = true)
#  |-- tBodyAccMag-entropy(): double (nullable = true)
#  |-- tBodyAccMag-arCoeff()1: double (nullable = true)
#  |-- tBodyAccMag-arCoeff()2: double (nullable = true)
#  |-- tBodyAccMag-arCoeff()3: double (nullable = true)
#  |-- tBodyAccMag-arCoeff()4: double (nullable = true)
#  |-- tGravityAccMag-mean(): double (nullable = true)
#  |-- tGravityAccMag-std(): double (nullable = true)
#  |-- tGravityAccMag-mad(): double (nullable = true)
#  |-- tGravityAccMag-max(): double (nullable = true)
#  |-- tGravityAccMag-min(): double (nullable = true)
#  |-- tGravityAccMag-sma(): double (nullable = true)
#  |-- tGravityAccMag-energy(): double (nullable = true)
#  |-- tGravityAccMag-iqr(): double (nullable = true)
#  |-- tGravityAccMag-entropy(): double (nullable = true)
#  |-- tGravityAccMag-arCoeff()1: double (nullable = true)
#  |-- tGravityAccMag-arCoeff()2: double (nullable = true)
#  |-- tGravityAccMag-arCoeff()3: double (nullable = true)
#  |-- tGravityAccMag-arCoeff()4: double (nullable = true)
#  |-- tBodyAccJerkMag-mean(): double (nullable = true)
#  |-- tBodyAccJerkMag-std(): double (nullable = true)
#  |-- tBodyAccJerkMag-mad(): double (nullable = true)
#  |-- tBodyAccJerkMag-max(): double (nullable = true)
#  |-- tBodyAccJerkMag-min(): double (nullable = true)
#  |-- tBodyAccJerkMag-sma(): double (nullable = true)
#  |-- tBodyAccJerkMag-energy(): double (nullable = true)
#  |-- tBodyAccJerkMag-iqr(): double (nullable = true)
#  |-- tBodyAccJerkMag-entropy(): double (nullable = true)
#  |-- tBodyAccJerkMag-arCoeff()1: double (nullable = true)
#  |-- tBodyAccJerkMag-arCoeff()2: double (nullable = true)
#  |-- tBodyAccJerkMag-arCoeff()3: double (nullable = true)
#  |-- tBodyAccJerkMag-arCoeff()4: double (nullable = true)
#  |-- tBodyGyroMag-mean(): double (nullable = true)
#  |-- tBodyGyroMag-std(): double (nullable = true)
#  |-- tBodyGyroMag-mad(): double (nullable = true)
#  |-- tBodyGyroMag-max(): double (nullable = true)
#  |-- tBodyGyroMag-min(): double (nullable = true)
#  |-- tBodyGyroMag-sma(): double (nullable = true)
#  |-- tBodyGyroMag-energy(): double (nullable = true)
#  |-- tBodyGyroMag-iqr(): double (nullable = true)
#  |-- tBodyGyroMag-entropy(): double (nullable = true)
#  |-- tBodyGyroMag-arCoeff()1: double (nullable = true)
#  |-- tBodyGyroMag-arCoeff()2: double (nullable = true)
#  |-- tBodyGyroMag-arCoeff()3: double (nullable = true)
#  |-- tBodyGyroMag-arCoeff()4: double (nullable = true)
#  |-- tBodyGyroJerkMag-mean(): double (nullable = true)
#  |-- tBodyGyroJerkMag-std(): double (nullable = true)
#  |-- tBodyGyroJerkMag-mad(): double (nullable = true)
#  |-- tBodyGyroJerkMag-max(): double (nullable = true)
#  |-- tBodyGyroJerkMag-min(): double (nullable = true)
#  |-- tBodyGyroJerkMag-sma(): double (nullable = true)
#  |-- tBodyGyroJerkMag-energy(): double (nullable = true)
#  |-- tBodyGyroJerkMag-iqr(): double (nullable = true)
#  |-- tBodyGyroJerkMag-entropy(): double (nullable = true)
#  |-- tBodyGyroJerkMag-arCoeff()1: double (nullable = true)
#  |-- tBodyGyroJerkMag-arCoeff()2: double (nullable = true)
#  |-- tBodyGyroJerkMag-arCoeff()3: double (nullable = true)
#  |-- tBodyGyroJerkMag-arCoeff()4: double (nullable = true)
#  |-- fBodyAcc-mean()-X: double (nullable = true)
#  |-- fBodyAcc-mean()-Y: double (nullable = true)
#  |-- fBodyAcc-mean()-Z: double (nullable = true)
#  |-- fBodyAcc-std()-X: double (nullable = true)
#  |-- fBodyAcc-std()-Y: double (nullable = true)
#  |-- fBodyAcc-std()-Z: double (nullable = true)
#  |-- fBodyAcc-mad()-X: double (nullable = true)
#  |-- fBodyAcc-mad()-Y: double (nullable = true)
#  |-- fBodyAcc-mad()-Z: double (nullable = true)
#  |-- fBodyAcc-max()-X: double (nullable = true)
#  |-- fBodyAcc-max()-Y: double (nullable = true)
#  |-- fBodyAcc-max()-Z: double (nullable = true)
#  |-- fBodyAcc-min()-X: double (nullable = true)
#  |-- fBodyAcc-min()-Y: double (nullable = true)
#  |-- fBodyAcc-min()-Z: double (nullable = true)
#  |-- fBodyAcc-sma(): double (nullable = true)
#  |-- fBodyAcc-energy()-X: double (nullable = true)
#  |-- fBodyAcc-energy()-Y: double (nullable = true)
#  |-- fBodyAcc-energy()-Z: double (nullable = true)
#  |-- fBodyAcc-iqr()-X: double (nullable = true)
#  |-- fBodyAcc-iqr()-Y: double (nullable = true)
#  |-- fBodyAcc-iqr()-Z: double (nullable = true)
#  |-- fBodyAcc-entropy()-X: double (nullable = true)
#  |-- fBodyAcc-entropy()-Y: double (nullable = true)
#  |-- fBodyAcc-entropy()-Z: double (nullable = true)
#  |-- fBodyAcc-maxInds-X: double (nullable = true)
#  |-- fBodyAcc-maxInds-Y: double (nullable = true)
#  |-- fBodyAcc-maxInds-Z: double (nullable = true)
#  |-- fBodyAcc-meanFreq()-X: double (nullable = true)
#  |-- fBodyAcc-meanFreq()-Y: double (nullable = true)
#  |-- fBodyAcc-meanFreq()-Z: double (nullable = true)
#  |-- fBodyAcc-skewness()-X: double (nullable = true)
#  |-- fBodyAcc-kurtosis()-X: double (nullable = true)
#  |-- fBodyAcc-skewness()-Y: double (nullable = true)
#  |-- fBodyAcc-kurtosis()-Y: double (nullable = true)
#  |-- fBodyAcc-skewness()-Z: double (nullable = true)
#  |-- fBodyAcc-kurtosis()-Z: double (nullable = true)
#  |-- fBodyAcc-bandsEnergy()-1,8302: double (nullable = true)
#  |-- fBodyAcc-bandsEnergy()-9,16303: double (nullable = true)
#  |-- fBodyAcc-bandsEnergy()-17,24304: double (nullable = true)
#  |-- fBodyAcc-bandsEnergy()-25,32305: double (nullable = true)
#  |-- fBodyAcc-bandsEnergy()-33,40306: double (nullable = true)
#  |-- fBodyAcc-bandsEnergy()-41,48307: double (nullable = true)
#  |-- fBodyAcc-bandsEnergy()-49,56308: double (nullable = true)
#  |-- fBodyAcc-bandsEnergy()-57,64309: double (nullable = true)
#  |-- fBodyAcc-bandsEnergy()-1,16310: double (nullable = true)
#  |-- fBodyAcc-bandsEnergy()-17,32311: double (nullable = true)
#  |-- fBodyAcc-bandsEnergy()-33,48312: double (nullable = true)
#  |-- fBodyAcc-bandsEnergy()-49,64313: double (nullable = true)
#  |-- fBodyAcc-bandsEnergy()-1,24314: double (nullable = true)
#  |-- fBodyAcc-bandsEnergy()-25,48315: double (nullable = true)
#  |-- fBodyAcc-bandsEnergy()-1,8316: double (nullable = true)
#  |-- fBodyAcc-bandsEnergy()-9,16317: double (nullable = true)
#  |-- fBodyAcc-bandsEnergy()-17,24318: double (nullable = true)
#  |-- fBodyAcc-bandsEnergy()-25,32319: double (nullable = true)
#  |-- fBodyAcc-bandsEnergy()-33,40320: double (nullable = true)
#  |-- fBodyAcc-bandsEnergy()-41,48321: double (nullable = true)
#  |-- fBodyAcc-bandsEnergy()-49,56322: double (nullable = true)
#  |-- fBodyAcc-bandsEnergy()-57,64323: double (nullable = true)
#  |-- fBodyAcc-bandsEnergy()-1,16324: double (nullable = true)
#  |-- fBodyAcc-bandsEnergy()-17,32325: double (nullable = true)
#  |-- fBodyAcc-bandsEnergy()-33,48326: double (nullable = true)
#  |-- fBodyAcc-bandsEnergy()-49,64327: double (nullable = true)
#  |-- fBodyAcc-bandsEnergy()-1,24328: double (nullable = true)
#  |-- fBodyAcc-bandsEnergy()-25,48329: double (nullable = true)
#  |-- fBodyAcc-bandsEnergy()-1,8330: double (nullable = true)
#  |-- fBodyAcc-bandsEnergy()-9,16331: double (nullable = true)
#  |-- fBodyAcc-bandsEnergy()-17,24332: double (nullable = true)
#  |-- fBodyAcc-bandsEnergy()-25,32333: double (nullable = true)
#  |-- fBodyAcc-bandsEnergy()-33,40334: double (nullable = true)
#  |-- fBodyAcc-bandsEnergy()-41,48335: double (nullable = true)
#  |-- fBodyAcc-bandsEnergy()-49,56336: double (nullable = true)
#  |-- fBodyAcc-bandsEnergy()-57,64337: double (nullable = true)
#  |-- fBodyAcc-bandsEnergy()-1,16338: double (nullable = true)
#  |-- fBodyAcc-bandsEnergy()-17,32339: double (nullable = true)
#  |-- fBodyAcc-bandsEnergy()-33,48340: double (nullable = true)
#  |-- fBodyAcc-bandsEnergy()-49,64341: double (nullable = true)
#  |-- fBodyAcc-bandsEnergy()-1,24342: double (nullable = true)
#  |-- fBodyAcc-bandsEnergy()-25,48343: double (nullable = true)
#  |-- fBodyAccJerk-mean()-X: double (nullable = true)
#  |-- fBodyAccJerk-mean()-Y: double (nullable = true)
#  |-- fBodyAccJerk-mean()-Z: double (nullable = true)
#  |-- fBodyAccJerk-std()-X: double (nullable = true)
#  |-- fBodyAccJerk-std()-Y: double (nullable = true)
#  |-- fBodyAccJerk-std()-Z: double (nullable = true)
#  |-- fBodyAccJerk-mad()-X: double (nullable = true)
#  |-- fBodyAccJerk-mad()-Y: double (nullable = true)
#  |-- fBodyAccJerk-mad()-Z: double (nullable = true)
#  |-- fBodyAccJerk-max()-X: double (nullable = true)
#  |-- fBodyAccJerk-max()-Y: double (nullable = true)
#  |-- fBodyAccJerk-max()-Z: double (nullable = true)
#  |-- fBodyAccJerk-min()-X: double (nullable = true)
#  |-- fBodyAccJerk-min()-Y: double (nullable = true)
#  |-- fBodyAccJerk-min()-Z: double (nullable = true)
#  |-- fBodyAccJerk-sma(): double (nullable = true)
#  |-- fBodyAccJerk-energy()-X: double (nullable = true)
#  |-- fBodyAccJerk-energy()-Y: double (nullable = true)
#  |-- fBodyAccJerk-energy()-Z: double (nullable = true)
#  |-- fBodyAccJerk-iqr()-X: double (nullable = true)
#  |-- fBodyAccJerk-iqr()-Y: double (nullable = true)
#  |-- fBodyAccJerk-iqr()-Z: double (nullable = true)
#  |-- fBodyAccJerk-entropy()-X: double (nullable = true)
#  |-- fBodyAccJerk-entropy()-Y: double (nullable = true)
#  |-- fBodyAccJerk-entropy()-Z: double (nullable = true)
#  |-- fBodyAccJerk-maxInds-X: double (nullable = true)
#  |-- fBodyAccJerk-maxInds-Y: double (nullable = true)
#  |-- fBodyAccJerk-maxInds-Z: double (nullable = true)
#  |-- fBodyAccJerk-meanFreq()-X: double (nullable = true)
#  |-- fBodyAccJerk-meanFreq()-Y: double (nullable = true)
#  |-- fBodyAccJerk-meanFreq()-Z: double (nullable = true)
#  |-- fBodyAccJerk-skewness()-X: double (nullable = true)
#  |-- fBodyAccJerk-kurtosis()-X: double (nullable = true)
#  |-- fBodyAccJerk-skewness()-Y: double (nullable = true)
#  |-- fBodyAccJerk-kurtosis()-Y: double (nullable = true)
#  |-- fBodyAccJerk-skewness()-Z: double (nullable = true)
#  |-- fBodyAccJerk-kurtosis()-Z: double (nullable = true)
#  |-- fBodyAccJerk-bandsEnergy()-1,8381: double (nullable = true)
#  |-- fBodyAccJerk-bandsEnergy()-9,16382: double (nullable = true)
#  |-- fBodyAccJerk-bandsEnergy()-17,24383: double (nullable = true)
#  |-- fBodyAccJerk-bandsEnergy()-25,32384: double (nullable = true)
#  |-- fBodyAccJerk-bandsEnergy()-33,40385: double (nullable = true)
#  |-- fBodyAccJerk-bandsEnergy()-41,48386: double (nullable = true)
#  |-- fBodyAccJerk-bandsEnergy()-49,56387: double (nullable = true)
#  |-- fBodyAccJerk-bandsEnergy()-57,64388: double (nullable = true)
#  |-- fBodyAccJerk-bandsEnergy()-1,16389: double (nullable = true)
#  |-- fBodyAccJerk-bandsEnergy()-17,32390: double (nullable = true)
#  |-- fBodyAccJerk-bandsEnergy()-33,48391: double (nullable = true)
#  |-- fBodyAccJerk-bandsEnergy()-49,64392: double (nullable = true)
#  |-- fBodyAccJerk-bandsEnergy()-1,24393: double (nullable = true)
#  |-- fBodyAccJerk-bandsEnergy()-25,48394: double (nullable = true)
#  |-- fBodyAccJerk-bandsEnergy()-1,8395: double (nullable = true)
#  |-- fBodyAccJerk-bandsEnergy()-9,16396: double (nullable = true)
#  |-- fBodyAccJerk-bandsEnergy()-17,24397: double (nullable = true)
#  |-- fBodyAccJerk-bandsEnergy()-25,32398: double (nullable = true)
#  |-- fBodyAccJerk-bandsEnergy()-33,40399: double (nullable = true)
#  |-- fBodyAccJerk-bandsEnergy()-41,48400: double (nullable = true)
#  |-- fBodyAccJerk-bandsEnergy()-49,56401: double (nullable = true)
#  |-- fBodyAccJerk-bandsEnergy()-57,64402: double (nullable = true)
#  |-- fBodyAccJerk-bandsEnergy()-1,16403: double (nullable = true)
#  |-- fBodyAccJerk-bandsEnergy()-17,32404: double (nullable = true)
#  |-- fBodyAccJerk-bandsEnergy()-33,48405: double (nullable = true)
#  |-- fBodyAccJerk-bandsEnergy()-49,64406: double (nullable = true)
#  |-- fBodyAccJerk-bandsEnergy()-1,24407: double (nullable = true)
#  |-- fBodyAccJerk-bandsEnergy()-25,48408: double (nullable = true)
#  |-- fBodyAccJerk-bandsEnergy()-1,8409: double (nullable = true)
#  |-- fBodyAccJerk-bandsEnergy()-9,16410: double (nullable = true)
#  |-- fBodyAccJerk-bandsEnergy()-17,24411: double (nullable = true)
#  |-- fBodyAccJerk-bandsEnergy()-25,32412: double (nullable = true)
#  |-- fBodyAccJerk-bandsEnergy()-33,40413: double (nullable = true)
#  |-- fBodyAccJerk-bandsEnergy()-41,48414: double (nullable = true)
#  |-- fBodyAccJerk-bandsEnergy()-49,56415: double (nullable = true)
#  |-- fBodyAccJerk-bandsEnergy()-57,64416: double (nullable = true)
#  |-- fBodyAccJerk-bandsEnergy()-1,16417: double (nullable = true)
#  |-- fBodyAccJerk-bandsEnergy()-17,32418: double (nullable = true)
#  |-- fBodyAccJerk-bandsEnergy()-33,48419: double (nullable = true)
#  |-- fBodyAccJerk-bandsEnergy()-49,64420: double (nullable = true)
#  |-- fBodyAccJerk-bandsEnergy()-1,24421: double (nullable = true)
#  |-- fBodyAccJerk-bandsEnergy()-25,48422: double (nullable = true)
#  |-- fBodyGyro-mean()-X: double (nullable = true)
#  |-- fBodyGyro-mean()-Y: double (nullable = true)
#  |-- fBodyGyro-mean()-Z: double (nullable = true)
#  |-- fBodyGyro-std()-X: double (nullable = true)
#  |-- fBodyGyro-std()-Y: double (nullable = true)
#  |-- fBodyGyro-std()-Z: double (nullable = true)
#  |-- fBodyGyro-mad()-X: double (nullable = true)
#  |-- fBodyGyro-mad()-Y: double (nullable = true)
#  |-- fBodyGyro-mad()-Z: double (nullable = true)
#  |-- fBodyGyro-max()-X: double (nullable = true)
#  |-- fBodyGyro-max()-Y: double (nullable = true)
#  |-- fBodyGyro-max()-Z: double (nullable = true)
#  |-- fBodyGyro-min()-X: double (nullable = true)
#  |-- fBodyGyro-min()-Y: double (nullable = true)
#  |-- fBodyGyro-min()-Z: double (nullable = true)
#  |-- fBodyGyro-sma(): double (nullable = true)
#  |-- fBodyGyro-energy()-X: double (nullable = true)
#  |-- fBodyGyro-energy()-Y: double (nullable = true)
#  |-- fBodyGyro-energy()-Z: double (nullable = true)
#  |-- fBodyGyro-iqr()-X: double (nullable = true)
#  |-- fBodyGyro-iqr()-Y: double (nullable = true)
#  |-- fBodyGyro-iqr()-Z: double (nullable = true)
#  |-- fBodyGyro-entropy()-X: double (nullable = true)
#  |-- fBodyGyro-entropy()-Y: double (nullable = true)
#  |-- fBodyGyro-entropy()-Z: double (nullable = true)
#  |-- fBodyGyro-maxInds-X: double (nullable = true)
#  |-- fBodyGyro-maxInds-Y: double (nullable = true)
#  |-- fBodyGyro-maxInds-Z: double (nullable = true)
#  |-- fBodyGyro-meanFreq()-X: double (nullable = true)
#  |-- fBodyGyro-meanFreq()-Y: double (nullable = true)
#  |-- fBodyGyro-meanFreq()-Z: double (nullable = true)
#  |-- fBodyGyro-skewness()-X: double (nullable = true)
#  |-- fBodyGyro-kurtosis()-X: double (nullable = true)
#  |-- fBodyGyro-skewness()-Y: double (nullable = true)
#  |-- fBodyGyro-kurtosis()-Y: double (nullable = true)
#  |-- fBodyGyro-skewness()-Z: double (nullable = true)
#  |-- fBodyGyro-kurtosis()-Z: double (nullable = true)
#  |-- fBodyGyro-bandsEnergy()-1,8460: double (nullable = true)
#  |-- fBodyGyro-bandsEnergy()-9,16461: double (nullable = true)
#  |-- fBodyGyro-bandsEnergy()-17,24462: double (nullable = true)
#  |-- fBodyGyro-bandsEnergy()-25,32463: double (nullable = true)
#  |-- fBodyGyro-bandsEnergy()-33,40464: double (nullable = true)
#  |-- fBodyGyro-bandsEnergy()-41,48465: double (nullable = true)
#  |-- fBodyGyro-bandsEnergy()-49,56466: double (nullable = true)
#  |-- fBodyGyro-bandsEnergy()-57,64467: double (nullable = true)
#  |-- fBodyGyro-bandsEnergy()-1,16468: double (nullable = true)
#  |-- fBodyGyro-bandsEnergy()-17,32469: double (nullable = true)
#  |-- fBodyGyro-bandsEnergy()-33,48470: double (nullable = true)
#  |-- fBodyGyro-bandsEnergy()-49,64471: double (nullable = true)
#  |-- fBodyGyro-bandsEnergy()-1,24472: double (nullable = true)
#  |-- fBodyGyro-bandsEnergy()-25,48473: double (nullable = true)
#  |-- fBodyGyro-bandsEnergy()-1,8474: double (nullable = true)
#  |-- fBodyGyro-bandsEnergy()-9,16475: double (nullable = true)
#  |-- fBodyGyro-bandsEnergy()-17,24476: double (nullable = true)
#  |-- fBodyGyro-bandsEnergy()-25,32477: double (nullable = true)
#  |-- fBodyGyro-bandsEnergy()-33,40478: double (nullable = true)
#  |-- fBodyGyro-bandsEnergy()-41,48479: double (nullable = true)
#  |-- fBodyGyro-bandsEnergy()-49,56480: double (nullable = true)
#  |-- fBodyGyro-bandsEnergy()-57,64481: double (nullable = true)
#  |-- fBodyGyro-bandsEnergy()-1,16482: double (nullable = true)
#  |-- fBodyGyro-bandsEnergy()-17,32483: double (nullable = true)
#  |-- fBodyGyro-bandsEnergy()-33,48484: double (nullable = true)
#  |-- fBodyGyro-bandsEnergy()-49,64485: double (nullable = true)
#  |-- fBodyGyro-bandsEnergy()-1,24486: double (nullable = true)
#  |-- fBodyGyro-bandsEnergy()-25,48487: double (nullable = true)
#  |-- fBodyGyro-bandsEnergy()-1,8488: double (nullable = true)
#  |-- fBodyGyro-bandsEnergy()-9,16489: double (nullable = true)
#  |-- fBodyGyro-bandsEnergy()-17,24490: double (nullable = true)
#  |-- fBodyGyro-bandsEnergy()-25,32491: double (nullable = true)
#  |-- fBodyGyro-bandsEnergy()-33,40492: double (nullable = true)
#  |-- fBodyGyro-bandsEnergy()-41,48493: double (nullable = true)
#  |-- fBodyGyro-bandsEnergy()-49,56494: double (nullable = true)
#  |-- fBodyGyro-bandsEnergy()-57,64495: double (nullable = true)
#  |-- fBodyGyro-bandsEnergy()-1,16496: double (nullable = true)
#  |-- fBodyGyro-bandsEnergy()-17,32497: double (nullable = true)
#  |-- fBodyGyro-bandsEnergy()-33,48498: double (nullable = true)
#  |-- fBodyGyro-bandsEnergy()-49,64499: double (nullable = true)
#  |-- fBodyGyro-bandsEnergy()-1,24500: double (nullable = true)
#  |-- fBodyGyro-bandsEnergy()-25,48501: double (nullable = true)
#  |-- fBodyAccMag-mean(): double (nullable = true)
#  |-- fBodyAccMag-std(): double (nullable = true)
#  |-- fBodyAccMag-mad(): double (nullable = true)
#  |-- fBodyAccMag-max(): double (nullable = true)
#  |-- fBodyAccMag-min(): double (nullable = true)
#  |-- fBodyAccMag-sma(): double (nullable = true)
#  |-- fBodyAccMag-energy(): double (nullable = true)
#  |-- fBodyAccMag-iqr(): double (nullable = true)
#  |-- fBodyAccMag-entropy(): double (nullable = true)
#  |-- fBodyAccMag-maxInds: double (nullable = true)
#  |-- fBodyAccMag-meanFreq(): double (nullable = true)
#  |-- fBodyAccMag-skewness(): double (nullable = true)
#  |-- fBodyAccMag-kurtosis(): double (nullable = true)
#  |-- fBodyBodyAccJerkMag-mean(): double (nullable = true)
#  |-- fBodyBodyAccJerkMag-std(): double (nullable = true)
#  |-- fBodyBodyAccJerkMag-mad(): double (nullable = true)
#  |-- fBodyBodyAccJerkMag-max(): double (nullable = true)
#  |-- fBodyBodyAccJerkMag-min(): double (nullable = true)
#  |-- fBodyBodyAccJerkMag-sma(): double (nullable = true)
#  |-- fBodyBodyAccJerkMag-energy(): double (nullable = true)
#  |-- fBodyBodyAccJerkMag-iqr(): double (nullable = true)
#  |-- fBodyBodyAccJerkMag-entropy(): double (nullable = true)
#  |-- fBodyBodyAccJerkMag-maxInds: double (nullable = true)
#  |-- fBodyBodyAccJerkMag-meanFreq(): double (nullable = true)
#  |-- fBodyBodyAccJerkMag-skewness(): double (nullable = true)
#  |-- fBodyBodyAccJerkMag-kurtosis(): double (nullable = true)
#  |-- fBodyBodyGyroMag-mean(): double (nullable = true)
#  |-- fBodyBodyGyroMag-std(): double (nullable = true)
#  |-- fBodyBodyGyroMag-mad(): double (nullable = true)
#  |-- fBodyBodyGyroMag-max(): double (nullable = true)
#  |-- fBodyBodyGyroMag-min(): double (nullable = true)
#  |-- fBodyBodyGyroMag-sma(): double (nullable = true)
#  |-- fBodyBodyGyroMag-energy(): double (nullable = true)
#  |-- fBodyBodyGyroMag-iqr(): double (nullable = true)
#  |-- fBodyBodyGyroMag-entropy(): double (nullable = true)
#  |-- fBodyBodyGyroMag-maxInds: double (nullable = true)
#  |-- fBodyBodyGyroMag-meanFreq(): double (nullable = true)
#  |-- fBodyBodyGyroMag-skewness(): double (nullable = true)
#  |-- fBodyBodyGyroMag-kurtosis(): double (nullable = true)
#  |-- fBodyBodyGyroJerkMag-mean(): double (nullable = true)
#  |-- fBodyBodyGyroJerkMag-std(): double (nullable = true)
#  |-- fBodyBodyGyroJerkMag-mad(): double (nullable = true)
#  |-- fBodyBodyGyroJerkMag-max(): double (nullable = true)
#  |-- fBodyBodyGyroJerkMag-min(): double (nullable = true)
#  |-- fBodyBodyGyroJerkMag-sma(): double (nullable = true)
#  |-- fBodyBodyGyroJerkMag-energy(): double (nullable = true)
#  |-- fBodyBodyGyroJerkMag-iqr(): double (nullable = true)
#  |-- fBodyBodyGyroJerkMag-entropy(): double (nullable = true)
#  |-- fBodyBodyGyroJerkMag-maxInds: double (nullable = true)
#  |-- fBodyBodyGyroJerkMag-meanFreq(): double (nullable = true)
#  |-- fBodyBodyGyroJerkMag-skewness(): double (nullable = true)
#  |-- fBodyBodyGyroJerkMag-kurtosis(): double (nullable = true)
#  |-- angle(tBodyAccMean,gravity): double (nullable = true)
#  |-- angle(tBodyAccJerkMean),gravityMean): double (nullable = true)
#  |-- angle(tBodyGyroMean,gravityMean): double (nullable = true)
#  |-- angle(tBodyGyroJerkMean,gravityMean): double (nullable = true)
#  |-- angle(X,gravityMean): double (nullable = true)
#  |-- angle(Y,gravityMean): double (nullable = true)
#  |-- angle(Z,gravityMean): double (nullable = true)
#  |-- Activity: string (nullable = true)

# %% [markdown]
# # Number of Unique Classes Present in the "Activity" Column

# %%
df.groupBy(df.Activity).count().show()
# Out:
# +------------------+-----+
# |          Activity|count|
# +------------------+-----+
# |            LAYING|  537|
# |WALKING_DOWNSTAIRS|  420|
# |           WALKING|  496|
# |          STANDING|  532|
# |  WALKING_UPSTAIRS|  471|
# |           SITTING|  491|
# +------------------+-----+

# %% [markdown]
# # Dimensions of the dataset

# %%
num_rows = df.count()
num_columns = len(df.columns)


print(f"The dataset has {num_rows} rows and {num_columns} columns.")
# Out:
# The dataset has 2947 rows and 562 columns.

# %% [markdown]
# # Prepare the Dataset for Logistic Regression Classification

# %%
from pyspark.ml.feature import VectorAssembler, StringIndexer

# Step 1: Assemble feature columns into a single vector column
assembler = VectorAssembler(inputCols=df.columns[:-1], outputCol="features")
data = assembler.transform(df)

# Preview the transformed data
data.show(5, truncate=False)
# Out:
# +-----------------+-----------------+-----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+--------------+-------------------+-------------------+-------------------+----------------+----------------+----------------+--------------------+--------------------+--------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+--------------------------+--------------------------+--------------------------+--------------------+--------------------+--------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-----------------+----------------------+----------------------+----------------------+-------------------+-------------------+-------------------+-----------------------+-----------------------+-----------------------+-------------------------+-------------------------+-------------------------+-------------------------+-------------------------+-------------------------+-------------------------+-------------------------+-------------------------+-------------------------+-------------------------+-------------------------+-----------------------------+-----------------------------+-----------------------------+---------------------+---------------------+---------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+-----------------------+-----------------------+-----------------------+--------------------+--------------------+--------------------+------------------------+------------------------+------------------------+--------------------------+--------------------------+--------------------------+--------------------------+--------------------------+--------------------------+--------------------------+--------------------------+--------------------------+--------------------------+--------------------------+--------------------------+------------------------------+------------------------------+------------------------------+------------------+------------------+------------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+---------------+--------------------+--------------------+--------------------+-----------------+-----------------+-----------------+---------------------+---------------------+---------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+---------------------------+---------------------------+---------------------------+----------------------+----------------------+----------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+-------------------+------------------------+------------------------+------------------------+---------------------+------------- ...
# |tBodyAcc-mean()-X|tBodyAcc-mean()-Y|tBodyAcc-mean()-Z|tBodyAcc-std()-X|tBodyAcc-std()-Y|tBodyAcc-std()-Z|tBodyAcc-mad()-X|tBodyAcc-mad()-Y|tBodyAcc-mad()-Z|tBodyAcc-max()-X|tBodyAcc-max()-Y|tBodyAcc-max()-Z|tBodyAcc-min()-X|tBodyAcc-min()-Y|tBodyAcc-min()-Z|tBodyAcc-sma()|tBodyAcc-energy()-X|tBodyAcc-energy()-Y|tBodyAcc-energy()-Z|tBodyAcc-iqr()-X|tBodyAcc-iqr()-Y|tBodyAcc-iqr()-Z|tBodyAcc-entropy()-X|tBodyAcc-entropy()-Y|tBodyAcc-entropy()-Z|tBodyAcc-arCoeff()-X,1|tBodyAcc-arCoeff()-X,2|tBodyAcc-arCoeff()-X,3|tBodyAcc-arCoeff()-X,4|tBodyAcc-arCoeff()-Y,1|tBodyAcc-arCoeff()-Y,2|tBodyAcc-arCoeff()-Y,3|tBodyAcc-arCoeff()-Y,4|tBodyAcc-arCoeff()-Z,1|tBodyAcc-arCoeff()-Z,2|tBodyAcc-arCoeff()-Z,3|tBodyAcc-arCoeff()-Z,4|tBodyAcc-correlation()-X,Y|tBodyAcc-correlation()-X,Z|tBodyAcc-correlation()-Y,Z|tGravityAcc-mean()-X|tGravityAcc-mean()-Y|tGravityAcc-mean()-Z|tGravityAcc-std()-X|tGravityAcc-std()-Y|tGravityAcc-std()-Z|tGravityAcc-mad()-X|tGravityAcc-mad()-Y|tGravityAcc-mad()-Z|tGravityAcc-max()-X|tGravityAcc-max()-Y|tGravityAcc-max()-Z|tGravityAcc-min()-X|tGravityAcc-min()-Y|tGravityAcc-min()-Z|tGravityAcc-sma()|tGravityAcc-energy()-X|tGravityAcc-energy()-Y|tGravityAcc-energy()-Z|tGravityAcc-iqr()-X|tGravityAcc-iqr()-Y|tGravityAcc-iqr()-Z|tGravityAcc-entropy()-X|tGravityAcc-entropy()-Y|tGravityAcc-entropy()-Z|tGravityAcc-arCoeff()-X,1|tGravityAcc-arCoeff()-X,2|tGravityAcc-arCoeff()-X,3|tGravityAcc-arCoeff()-X,4|tGravityAcc-arCoeff()-Y,1|tGravityAcc-arCoeff()-Y,2|tGravityAcc-arCoeff()-Y,3|tGravityAcc-arCoeff()-Y,4|tGravityAcc-arCoeff()-Z,1|tGravityAcc-arCoeff()-Z,2|tGravityAcc-arCoeff()-Z,3|tGravityAcc-arCoeff()-Z,4|tGravityAcc-correlation()-X,Y|tGravityAcc-correlation()-X,Z|tGravityAcc-correlation()-Y,Z|tBodyAccJerk-mean()-X|tBodyAccJerk-mean()-Y|tBodyAccJerk-mean()-Z|tBodyAccJerk-std()-X|tBodyAccJerk-std()-Y|tBodyAccJerk-std()-Z|tBodyAccJerk-mad()-X|tBodyAccJerk-mad()-Y|tBodyAccJerk-mad()-Z|tBodyAccJerk-max()-X|tBodyAccJerk-max()-Y|tBodyAccJerk-max()-Z|tBodyAccJerk-min()-X|tBodyAccJerk-min()-Y|tBodyAccJerk-min()-Z|tBodyAccJerk-sma()|tBodyAccJerk-energy()-X|tBodyAccJerk-energy()-Y|tBodyAccJerk-energy()-Z|tBodyAccJerk-iqr()-X|tBodyAccJerk-iqr()-Y|tBodyAccJerk-iqr()-Z|tBodyAccJerk-entropy()-X|tBodyAccJerk-entropy()-Y|tBodyAccJerk-entropy()-Z|tBodyAccJerk-arCoeff()-X,1|tBodyAccJerk-arCoeff()-X,2|tBodyAccJerk-arCoeff()-X,3|tBodyAccJerk-arCoeff()-X,4|tBodyAccJerk-arCoeff()-Y,1|tBodyAccJerk-arCoeff()-Y,2|tBodyAccJerk-arCoeff()-Y,3|tBodyAccJerk-arCoeff()-Y,4|tBodyAccJerk-arCoeff()-Z,1|tBodyAccJerk-arCoeff()-Z,2|tBodyAccJerk-arCoeff()-Z,3|tBodyAccJerk-arCoeff()-Z,4|tBodyAccJerk-correlation()-X,Y|tBodyAccJerk-correlation()-X,Z|tBodyAccJerk-correlation()-Y,Z|tBodyGyro-mean()-X|tBodyGyro-mean()-Y|tBodyGyro-mean()-Z|tBodyGyro-std()-X|tBodyGyro-std()-Y|tBodyGyro-std()-Z|tBodyGyro-mad()-X|tBodyGyro-mad()-Y|tBodyGyro-mad()-Z|tBodyGyro-max()-X|tBodyGyro-max()-Y|tBodyGyro-max()-Z|tBodyGyro-min()-X|tBodyGyro-min()-Y|tBodyGyro-min()-Z|tBodyGyro-sma()|tBodyGyro-energy()-X|tBodyGyro-energy()-Y|tBodyGyro-energy()-Z|tBodyGyro-iqr()-X|tBodyGyro-iqr()-Y|tBodyGyro-iqr()-Z|tBodyGyro-entropy()-X|tBodyGyro-entropy()-Y|tBodyGyro-entropy()-Z|tBodyGyro-arCoeff()-X,1|tBodyGyro-arCoeff()-X,2|tBodyGyro-arCoeff()-X,3|tBodyGyro-arCoeff()-X,4|tBodyGyro-arCoeff()-Y,1|tBodyGyro-arCoeff()-Y,2|tBodyGyro-arCoeff()-Y,3|tBodyGyro-arCoeff()-Y,4|tBodyGyro-arCoeff()-Z,1|tBodyGyro-arCoeff()-Z,2|tBodyGyro-arCoeff()-Z,3|tBodyGyro-arCoeff()-Z,4|tBodyGyro-correlation()-X,Y|tBodyGyro-correlation()-X,Z|tBodyGyro-correlation()-Y,Z|tBodyGyroJerk-mean()-X|tBodyGyroJerk-mean()-Y|tBodyGyroJerk-mean()-Z|tBodyGyroJer
------------+-----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+--------------+-------------------+-------------------+-------------------+----------------+----------------+----------------+--------------------+--------------------+--------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+--------------------------+--------------------------+--------------------------+--------------------+--------------------+--------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+-----------------+----------------------+----------------------+----------------------+-------------------+-------------------+-------------------+-----------------------+-----------------------+-----------------------+-------------------------+-------------------------+-------------------------+-------------------------+-------------------------+-------------------------+-------------------------+-------------------------+-------------------------+-------------------------+-------------------------+-------------------------+-----------------------------+-----------------------------+-----------------------------+---------------------+---------------------+---------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+-----------------------+-----------------------+-----------------------+--------------------+--------------------+--------------------+------------------------+------------------------+------------------------+--------------------------+--------------------------+--------------------------+--------------------------+--------------------------+--------------------------+--------------------------+--------------------------+--------------------------+--------------------------+--------------------------+--------------------------+------------------------------+------------------------------+------------------------------+------------------+------------------+------------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+-----------------+---------------+--------------------+--------------------+--------------------+-----------------+-----------------+-----------------+---------------------+---------------------+---------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+---------------------------+---------------------------+---------------------------+----------------------+----------------------+----------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+---------------------+-------------------+------------------------+------------------------+------------------------+---------------------+------------- ...
# only showing top 5 rows

# %%
# Step 2: Select relevant columns for machine learning
ML_data = data.select(data.features, data.Activity)

# Step 3: Index the 'Activity' column to convert it into numeric labels
indexer = StringIndexer(inputCol="Activity", outputCol="Activity_index")
indexed_data = indexer.fit(ML_data).transform(ML_data)

ML_data = indexed_data.drop("Activity")

ML_data.show(5)
# Out:
# +--------------------+--------------+
# |            features|Activity_index|
# +--------------------+--------------+
# |[0.25717778,-0.02...|           1.0|
# |[0.28602671,-0.01...|           1.0|
# |[0.27548482,-0.02...|           1.0|
# |[0.27029822,-0.03...|           1.0|
# |[0.27483295,-0.02...|           1.0|
# +--------------------+--------------+
# only showing top 5 rows

# %% [markdown]
# # Split the Dataset into Training and Testing Sets

# %%
# Split the dataset into training (80%) and testing (20%) sets
train, test = ML_data.randomSplit([0.8, 0.2], seed=3)

print(f"Training set size: {train.count()} rows")
print(f"Testing set size: {test.count()} rows")
# Out:
# Training set size: 2335 rows
# Testing set size: 612 rows

# %% [markdown]
# # Logistic Regression with 10-Fold Cross-Validation on Training Dataset

# %%
from pyspark.ml.classification import LogisticRegression
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator
from pyspark.ml.evaluation import MulticlassClassificationEvaluator

# Step 1: Initialize the Logistic Regression model
lr = LogisticRegression(labelCol='Activity_index', featuresCol='features')

# Step 2: Create a parameter grid for hyperparameter tuning
paramGrid = (ParamGridBuilder()
             .addGrid(lr.regParam, [0.1, 0.01])  # Regularization parameter
             .addGrid(lr.maxIter, [10, 20])      # Maximum number of iterations
             .build())

# Step 3: Define the evaluator for cross-validation
evaluator = MulticlassClassificationEvaluator(
    labelCol='Activity_index', predictionCol='prediction', metricName='accuracy'
)

# Step 4: Set up 10-fold cross-validation
cv = CrossValidator(
    estimator=lr,
    estimatorParamMaps=paramGrid,
    evaluator=evaluator,
    numFolds=10
)

# Step 5: Fit the model using the training dataset
cv_model = cv.fit(train)

# Best model parameters
best_model = cv_model.bestModel
print(f"Best Regularization Parameter: {best_model._java_obj.getRegParam()}")
print(f"Best Maximum Iterations: {best_model._java_obj.getMaxIter()}")
# Out:
# Best Regularization Parameter: 0.01
# Best Maximum Iterations: 20

# %% [markdown]
# # Evaluate the Best Model on the Testing Dataset

# %%
results = cv_model.transform(test)
f1_score = evaluator.evaluate(results)

print(f1_score)
# Out:
# 0.9771241830065359

# %% [markdown]
# # Multiclass Classification Evaluation (Accuracy, Precision, Recall, and F1-Score)

# %%
f1_score = evaluator.evaluate(results, {evaluator.metricName: 'f1'})
accuracy = evaluator.evaluate(results, {evaluator.metricName: 'accuracy'})
recall = evaluator.evaluate(results, {evaluator.metricName: 'weightedRecall'})
precision = evaluator.evaluate(results, {evaluator.metricName: 'weightedPrecision'})


print(f"F1-Score: {f1_score:.4f}")
print(f"Accuracy: {accuracy:.4f}")
print(f"Recall: {recall:.4f}")
print(f"Precision: {precision:.4f}")
# Out:
# F1-Score: 0.9770
# Accuracy: 0.9771
# Recall: 0.9771
# Precision: 0.9776

# %% [markdown]
# # Random Forest

# %% [markdown]
# ## Hyperparameter Tuning Using Grid Search

# %%
from pyspark.ml.classification import RandomForestClassifier

rf = RandomForestClassifier(labelCol='Activity_index', featuresCol='features')

paramGrid = (ParamGridBuilder()
             .addGrid(rf.maxDepth, [3, 5, 7, 9]) # Maximum depth of trees
             .addGrid(rf.numTrees, [10, 15, 20, 25]) # Number of trees
             .build())


cv = CrossValidator(estimator=rf, estimatorParamMaps=paramGrid, evaluator=evaluator, numFolds=10)

cv_model = cv.fit(test)

# %% [markdown]
# ## Best Hyperparameter Combination

# %%
# Extract the best maxDepth and numTrees
best_max_depth = cv_model.bestModel._java_obj.getMaxDepth()
best_num_trees = cv_model.bestModel._java_obj.getNumTrees()

print(f"Best maxDepth: {best_max_depth}")
print(f"Best numTrees: {best_num_trees}")
# Out:
# Best maxDepth: 9
# Best numTrees: 20

# %% [markdown]
# ## Extract Top 50 Important Features

# %%
# Get feature importances
feature_importances = cv_model.bestModel.featureImportances

# Sort and select the top 50 feature importances
sorted_features = sorted(feature_importances, reverse=True)
top_50_val = sorted_features[:50]

print(f"Top 50 Feature Importances: {top_50_val}")
# Out:
# Top 50 Feature Importances: [0.0340392536909586, 0.031304461235740516, 0.027520710057555957, 0.026881108068754954, 0.021337667532532172, 0.021123681529680485, 0.020374539052035248, 0.019095512622218758, 0.01858358859792021, 0.016716484702180606, 0.013584085443148139, 0.012623928005612477, 0.012326680513316327, 0.01168947404557031, 0.011615632963694585, 0.011415288142880306, 0.011391992348358167, 0.011223422780235536, 0.010863982576466872, 0.01071812455664469, 0.010533568387627782, 0.010442795694287044, 0.01034833906562523, 0.010322936962848124, 0.010269326078298236, 0.010177732448955023, 0.01017508116088863, 0.010154979045966931, 0.010138328461672213, 0.010137944912799693, 0.010124948081434632, 0.010047218150779373, 0.009958486827782644, 0.009764034580028627, 0.009509126784228215, 0.009238461965237367, 0.00899278901004865, 0.008816475411887842, 0.008808571836094287, 0.008107429263952078, 0.00740753329074732, 0.007355350710185965, 0.007165483467961535, 0.007081867071589028, 0.006913933939818485, 0.006898412968516156, 0.006719484888405709, 0.006718776871331254, 0.006348398039559754, 0.006032846992746079]

# %% [markdown]
# ## Subset the Dataset with Top 50 Features and the Activity Column

# %%
top_50_features = []


for i in range(len(feature_importances)):
  if feature_importances[i] in top_50_val:
    top_50_features.append(df.columns[i])

top_50_features.append('Activity')

df = df.select(top_50_features)
df.show()
# Out:
# +----------------+----------------+--------------------------+--------------------+-------------------+-------------------+-------------------+-------------------+-------------------+----------------------+----------------------+-----------------------+-------------------------+-------------------------+-------------------------+-------------------------+-------------------------+--------------------+------------------+-----------------------+---------------------+---------------------+---------------------+-----------------+----------------+----------------+---------------------+------------------------------+-------------------------------+--------------------+--------------------+------------------------+-----------------------------------+-----------------------------------+----------------------------------+-----------------------------------+-----------------------------------+----------------------------------+----------------------+-----------------+-----------------+-----------------+-----------------+----------------------+----------------------------+------------------------+---------------------------+--------------------+--------------------+--------------------+--------+
# |tBodyAcc-mad()-X|tBodyAcc-max()-X|tBodyAcc-correlation()-X,Y|tGravityAcc-mean()-Y|tGravityAcc-max()-X|tGravityAcc-max()-Y|tGravityAcc-min()-X|tGravityAcc-min()-Y|tGravityAcc-min()-Z|tGravityAcc-energy()-X|tGravityAcc-energy()-Y|tGravityAcc-entropy()-Y|tGravityAcc-arCoeff()-X,1|tGravityAcc-arCoeff()-X,2|tGravityAcc-arCoeff()-X,4|tGravityAcc-arCoeff()-Y,2|tGravityAcc-arCoeff()-Y,3|tBodyAccJerk-min()-X|tBodyAccJerk-sma()|tBodyAccJerk-energy()-Y|tBodyGyroJerk-mad()-X|tBodyGyroJerk-iqr()-X|tBodyAccJerkMag-iqr()|fBodyAcc-mean()-Y|fBodyAcc-std()-X|fBodyAcc-mad()-Y|fBodyAcc-meanFreq()-X|fBodyAcc-bandsEnergy()-1,16310|fBodyAcc-bandsEnergy()-17,32325|fBodyAccJerk-std()-Y|fBodyAccJerk-max()-X|fBodyAccJerk-entropy()-Y|fBodyAccJerk-bandsEnergy()-41,48386|fBodyAccJerk-bandsEnergy()-17,32390|fBodyAccJerk-bandsEnergy()-1,24393|fBodyAccJerk-bandsEnergy()-17,24397|fBodyAccJerk-bandsEnergy()-25,32398|fBodyAccJerk-bandsEnergy()-1,24407|fBodyGyro-skewness()-Y|fBodyAccMag-std()|fBodyAccMag-mad()|fBodyAccMag-sma()|fBodyAccMag-iqr()|fBodyAccMag-meanFreq()|fBodyBodyAccJerkMag-energy()|fBodyBodyGyroMag-maxInds|fBodyBodyGyroMag-meanFreq()|angle(X,gravityMean)|angle(Y,gravityMean)|angle(Z,gravityMean)|Activity|
# +----------------+----------------+--------------------------+--------------------+-------------------+-------------------+-------------------+-------------------+-------------------+----------------------+----------------------+-----------------------+-------------------------+-------------------------+-------------------------+-------------------------+-------------------------+--------------------+------------------+-----------------------+---------------------+---------------------+---------------------+-----------------+----------------+----------------+---------------------+------------------------------+-------------------------------+--------------------+--------------------+------------------------+-----------------------------------+-----------------------------------+----------------------------------+-----------------------------------+-----------------------------------+----------------------------------+----------------------+-----------------+-----------------+-----------------+-----------------+----------------------+----------------------------+------------------------+---------------------------+--------------------+--------------------+--------------------+--------+
# |     -0.97738718|     -0.91115208|                0.37277671|         -0.41889767|         0.81683546|        -0.43240732|         0.90517944|        -0.39426422|        0.038488707|            0.70723083|           -0.69005573|                   -1.0|               -0.2806391|               0.29271688|               0.31662741|                0.4185207|              -0.43419397|          0.93847568|       -0.96400196|            -0.99701073|          -0.96065192|          -0.97829903|          -0.95180714|       -0.9008582|     -0.97563293|     -0.90152253|           0.12067035|                   -0.99958712|                      -0.996666|         -0.93728902|         -0.96084117|             -0.57464283|                        -0.99894435|                        -0.99732021|                       -0.99936156|                        -0.99672319|                        -0.99859057|                       -0.99699272|           -0.53681724|      -0.92558908|      -0.93594808|      -0.93889729|      -0.95813759|          -0.031525295|                 -0.99707955|                    -1.0|                -0.33818405|          -0.6014156|          0.37197819|         -0.01046071|STANDING|
# +----------------+----------------+--------------------------+--------------------+-------------------+-------------------+-------------------+-------------------+-------------------+----------------------+----------------------+-----------------------+-------------------------+-------------------------+-------------------------+-------------------------+-------------------------+--------------------+------------------+-----------------------+---------------------+---------------------+---------------------+-----------------+----------------+----------------+---------------------+------------------------------+-------------------------------+--------------------+--------------------+------------------------+-----------------------------------+-----------------------------------+----------------------------------+-----------------------------------+-----------------------------------+----------------------------------+----------------------+-----------------+-----------------+-----------------+-----------------+----------------------+----------------------------+------------------------+---------------------------+--------------------+--------------------+--------------------+--------+
# only showing top 20 rows

# %% [markdown]
# # Logistic Regression on the New Subset Dataset (50 Features + Activity Label)

# %%
from pyspark.ml.feature import VectorAssembler, StringIndexer
from pyspark.ml.classification import LogisticRegression
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator
from pyspark.ml.evaluation import MulticlassClassificationEvaluator

# Step 1: Assemble the top 50 features into a single vector column
assembler = VectorAssembler(inputCols=df.columns[:-1], outputCol='features')
data = assembler.transform(df)

# Step 2: Prepare the dataset for machine learning
ML_data = data.select(data.features, data.Activity)

# Step 3: Index the 'Activity' column to numeric labels
indexer = StringIndexer(inputCol="Activity", outputCol="Activity_index")
indexed_data = indexer.fit(ML_data).transform(ML_data)


ML_data = indexed_data.drop('Activity')
train, test = ML_data.randomSplit([0.8, 0.2], seed=3)


lr = LogisticRegression(labelCol='Activity_index', featuresCol='features')

paramGrid = (ParamGridBuilder()
             .addGrid(lr.regParam, [0.1, 0.01]) # Regularization parameter
             .addGrid(lr.maxIter, [10, 20])     # Maximum iterations
             .build())

evaluator = MulticlassClassificationEvaluator(labelCol='Activity_index', predictionCol='prediction')
cv = CrossValidator(estimator=lr, estimatorParamMaps=paramGrid, evaluator=evaluator, numFolds=10)
cv_model = cv.fit(train)

results = cv_model.transform(test)
f1_score = evaluator.evaluate(results)

print(f"The F1-score of the Logistic Regression model on the testing dataset is: {f1_score:.4f}")
# Out:
# The F1-score of the Logistic Regression model on the testing dataset is: 0.9182

# %% [markdown]
# # Compare Accuracy Between Logistic Regression Models (Full Dataset vs. Subset)

# %%
# Evaluate accuracy of the logistic regression model on the subset dataset
accuracy_subset = evaluator.evaluate(results, {evaluator.metricName: 'accuracy'})

print(f"Accuracy of the logistic regression model with the subset dataset: {accuracy_subset:.4f}")
# Out:
# Accuracy of the logistic regression model with the subset dataset: 0.9183

# %% [markdown]
# * The logistic regression model using the **whole dataset** (Task 7) produced better accuracy compared to the model using the **subset dataset** (Task 9).
# * This could indicate that the features excluded in the subset might have carried significant predictive power or that reducing the feature set led to a loss of important information.
